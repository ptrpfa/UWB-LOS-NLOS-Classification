# %%
from utils import *
from config import *
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

from yellowbrick.classifier import ClassificationReport

# %%
# Import dict list of pkl 
dict_combined_datasets_metadata = load_from_pickle("./dataset/dict_datasets.pkl", False)

# %%
# Add column names
columns = ['Dataset_index','Name', 'Train_Accuracy', 'Train_Precision', 'Test_Accuracy', 'Test_Precision']

# Create DataFrame
result_df = pd.DataFrame(columns=columns)
result_df
# Out:
# Empty DataFrame
# Columns: [Dataset_index, Name, Train_Accuracy, Train_Precision, Test_Accuracy, Test_Precision]
# Index: []

# %%
# Load the datasets into separate df
index = 0

for k, v in dict_combined_datasets_metadata.items():
    exec(f'dataset_{index} = load_from_pickle(f\"./dataset/{v}\", False)')
    df = pd.DataFrame([[index, k]], columns=['Dataset_index', 'Name'])
    result_df = pd.concat([result_df, df], ignore_index=True)
    index += 1

# %%
result_df
# Out:
#    Dataset_index                                               Name  \
# 0              0                                         noncir_cir
# 1              1                               noncir_cir_mm_scaled
# 2              2                               noncir_cir_ss_scaled
# 3              3                                   noncir_cir_stats
# 4              4                         noncir_cir_stats_mm_scaled
# ..           ...                                                ...
# 67            67  noncir_ss_scaled_trimmed_cir_stats_mm_scaled_t...
# 68            68  noncir_ss_scaled_trimmed_cir_stats_ss_scaled_t...
# 69            69                   noncir_ss_scaled_trimmed_cir_pca
# 70            70         noncir_ss_scaled_trimmed_cir_pca_mm_scaled
# 71            71         noncir_ss_scaled_trimmed_cir_pca_ss_scaled
#
#    Train_Accuracy Train_Precision Test_Accuracy Test_Precision
# 0             NaN             NaN           NaN            NaN
# 1             NaN             NaN           NaN            NaN
# 2             NaN             NaN           NaN            NaN
# 3             NaN             NaN           NaN            NaN
# 4             NaN             NaN           NaN            NaN
# ..            ...             ...           ...            ...
# 67            NaN             NaN           NaN            NaN
# 68            NaN             NaN           NaN            NaN
# 69            NaN             NaN           NaN            NaN
# 70            NaN             NaN           NaN            NaN
# 71            NaN             NaN           NaN            NaN
#
# [72 rows x 6 columns]

# %%
# Select the features to be used for Support Vector Classification
# Define features and target variable
X = dataset_0.drop('NLOS', axis=1)
y = dataset_0['NLOS']

# Split data into train and test sets (70:30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# Train Random Forest classifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
""" Random Forest Model Performance """

# Testing Accuracy
y_test_pred = rf_classifier.predict(X_test)
results = classifier_metrics(list(y_test), y_test_pred, print_results=True)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=results["cm"], display_labels=rf_classifier.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Random Forest)')
plt.show()
# Out:
# Accuracy: 0.8742857142857143
# Precision: 0.8777793024030317
# Recall: 0.8749215160562853
# F1 Score: 0.8741090546209667
# Mean Squared Error (MSE): 0.12571428571428572
# Matthews Correlation Coefficient (MCC): 0.7526953933474829
# Cohen's Kappa: 0.7488588772719398
# Hamming Loss: 0.12571428571428572
#
# Confusion Matrix:
#  [[5744  474]
#  [1110 5272]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600

# %%
""" Random Forest Model Performance """

# Training Accuracy
y_train_pred = rf_classifier.predict(X_train)
results = classifier_metrics(list(y_train), y_train_pred, print_results=True)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=results["cm"], display_labels=rf_classifier.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix (Random Forest)')
plt.show()
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
# Select the first 10 dataset to be used for Random Forest

for index in range(0, 10):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_0: noncir_cir...
# Accuracy: 0.8749206349206349
# Precision: 0.8779675361851847
# Recall: 0.8755152170400448
# F1 Score: 0.874773429809554
# Mean Squared Error (MSE): 0.12507936507936507
# Matthews Correlation Coefficient (MCC): 0.7534787625001003
# Cohen's Kappa: 0.7501066390873204
# Hamming Loss: 0.12507936507936507
#
# Confusion Matrix:
#  [[5728  490]
#  [1086 5296]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.88      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_1: noncir_cir_mm_scaled...
# Accuracy: 0.8740476190476191
# Precision: 0.877321335328912
# Recall: 0.8746637500391853
# F1 Score: 0.8738846056061466
# Mean Squared Error (MSE): 0.12595238095238095
# Matthews Correlation Coefficient (MCC): 0.7519803892765372
# Cohen's Kappa: 0.7483733650912936
# Hamming Loss: 0.12595238095238095
#
# Confusion Matrix:
#  [[5733  485]
#  [1102 5280]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_2: noncir_cir_ss_scaled...
# Accuracy: 0.8727777777777778
# Precision: 0.8762017278146907
# Recall: 0.8734081581369442
# F1 Score: 0.8726027718941776
# Mean Squared Error (MSE): 0.1272222222222222
# Matthews Correlation Coefficient (MCC): 0.7496046805382679
# Cohen's Kappa: 0.7458438297423196
# Hamming Loss: 0.1272222222222222
#
# Confusion Matrix:
#  [[5732  486]
#  [1117 5265]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.82      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_3: noncir_cir_stats...
# Accuracy: 0.917063492063492
# Precision: 0.9174677627326231
# Recall: 0.9172922366590903
# F1 Score: 0.9170608585524562
# Mean Squared Error (MSE): 0.08293650793650793
# Matthews Correlation Coefficient (MCC): 0.834759980937665
# Cohen's Kappa: 0.8341793999810491
# Hamming Loss: 0.08293650793650793
#
# Confusion Matrix:
#  [[5813  405]
#  [ 640 5742]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_4: noncir_cir_stats_mm_scaled...
# Accuracy: 0.915079365079365
# Precision: 0.9154615336213767
# Recall: 0.9153026075770558
# F1 Score: 0.9150770349934771
# Mean Squared Error (MSE): 0.08492063492063492
# Matthews Correlation Coefficient (MCC): 0.8307641259970737
# Cohen's Kappa: 0.8302106466009789
# Hamming Loss: 0.08492063492063492
#
# Confusion Matrix:
#  [[5798  420]
#  [ 650 5732]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_5: noncir_cir_stats_ss_scaled...
# Accuracy: 0.915079365079365
# Precision: 0.9154867141071243
# Recall: 0.9153088066620306
# F1 Score: 0.9150765920701266
# Mean Squared Error (MSE): 0.08492063492063492
# Matthews Correlation Coefficient (MCC): 0.830795501720509
# Cohen's Kappa: 0.8302127506521735
# Hamming Loss: 0.08492063492063492
#
# Confusion Matrix:
#  [[5801  417]
#  [ 653 5729]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_6: noncir_cir_stats_trimmed...
# Accuracy: 0.9161904761904762
# Precision: 0.9165899948410382
# Recall: 0.9164180396799901
# F1 Score: 0.9161878893969391
# Mean Squared Error (MSE): 0.0838095238095238
# Matthews Correlation Coefficient (MCC): 0.8330080167729536
# Cohen's Kappa: 0.8324335738960685
# Hamming Loss: 0.0838095238095238
#
# Confusion Matrix:
#  [[5807  411]
#  [ 645 5737]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_7: noncir_cir_stats_mm_scaled_trimmed...
# Accuracy: 0.9169047619047619
# Precision: 0.9173089389002448
# Recall: 0.9171334796048592
# F1 Score: 0.9169021233535136
# Mean Squared Error (MSE): 0.0830952380952381
# Matthews Correlation Coefficient (MCC): 0.8344424000580765
# Cohen's Kappa: 0.8338620399810128
# Hamming Loss: 0.0830952380952381
#
# Confusion Matrix:
#  [[5812  406]
#  [ 641 5741]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999319727891156
# Precision: 0.9999319706722699
# Recall: 0.9999319706722699
# F1 Score: 0.9999319706722699
# Mean Squared Error (MSE): 6.802721088435374e-05
# Matthews Correlation Coefficient (MCC): 0.9998639413445398
# Cohen's Kappa: 0.9998639413445398
# Hamming Loss: 6.802721088435374e-05
#
# Confusion Matrix:
#  [[14781     1]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_8: noncir_cir_stats_ss_scaled_trimmed...
# Accuracy: 0.9161111111111111
# Precision: 0.9164815198779399
# Recall: 0.9163314288870708
# F1 Score: 0.916109013836457
# Mean Squared Error (MSE): 0.08388888888888889
# Matthews Correlation Coefficient (MCC): 0.8328129352401815
# Cohen's Kappa: 0.8322724686406617
# Hamming Loss: 0.08388888888888889
#
# Confusion Matrix:
#  [[5803  415]
#  [ 642 5740]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_9: noncir_cir_pca...
# Accuracy: 0.9014285714285715
# Precision: 0.9025950835778832
# Recall: 0.9017982789525744
# F1 Score: 0.9014011828682571
# Mean Squared Error (MSE): 0.09857142857142857
# Matthews Correlation Coefficient (MCC): 0.8043929678866203
# Cohen's Kappa: 0.8029760025848856
# Hamming Loss: 0.09857142857142857
#
# Confusion Matrix:
#  [[5784  434]
#  [ 808 5574]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.87      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_df
# Out:
#    Dataset_index                                               Name  \
# 0              0                                         noncir_cir
# 1              1                               noncir_cir_mm_scaled
# 2              2                               noncir_cir_ss_scaled
# 3              3                                   noncir_cir_stats
# 4              4                         noncir_cir_stats_mm_scaled
# ..           ...                                                ...
# 67            67  noncir_ss_scaled_trimmed_cir_stats_mm_scaled_t...
# 68            68  noncir_ss_scaled_trimmed_cir_stats_ss_scaled_t...
# 69            69                   noncir_ss_scaled_trimmed_cir_pca
# 70            70         noncir_ss_scaled_trimmed_cir_pca_mm_scaled
# 71            71         noncir_ss_scaled_trimmed_cir_pca_ss_scaled
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 0         1.000000         1.000000       0.874921        0.877968
# 1         1.000000         1.000000       0.874048        0.877321
# 2         1.000000         1.000000       0.872778        0.876202
# 3         1.000000         1.000000       0.917063        0.917468
# 4         0.999966         0.999966       0.915079        0.915462
# ..             ...              ...            ...             ...
# 67             NaN              NaN            NaN             NaN
# 68             NaN              NaN            NaN             NaN
# 69             NaN              NaN            NaN             NaN
# 70             NaN              NaN            NaN             NaN
# 71             NaN              NaN            NaN             NaN
#
# [72 rows x 6 columns]

# %%
# Select the second 10 dataset to be used for Random Forest

for index in range(10, 20):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_10: noncir_cir_pca_mm_scaled...
# Accuracy: 0.9027777777777778
# Precision: 0.9037788357122472
# Recall: 0.9031218843928107
# F1 Score: 0.9027568143863214
# Mean Squared Error (MSE): 0.09722222222222222
# Matthews Correlation Coefficient (MCC): 0.8069004526712231
# Cohen's Kappa: 0.8056627568556665
# Hamming Loss: 0.09722222222222222
#
# Confusion Matrix:
#  [[5780  438]
#  [ 787 5595]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_11: noncir_cir_pca_ss_scaled...
# Accuracy: 0.9022222222222223
# Precision: 0.9033904430015642
# Recall: 0.90259206422373
# F1 Score: 0.9021950541817172
# Mean Squared Error (MSE): 0.09777777777777778
# Matthews Correlation Coefficient (MCC): 0.8059821118018058
# Cohen's Kappa: 0.8045623471695483
# Hamming Loss: 0.09777777777777778
#
# Confusion Matrix:
#  [[5789  429]
#  [ 803 5579]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.87      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_12: noncir_mm_scaled_cir...
# Accuracy: 0.8723809523809524
# Precision: 0.8758596965133558
# Recall: 0.873016431405512
# F1 Score: 0.8722016160546178
# Mean Squared Error (MSE): 0.12761904761904763
# Matthews Correlation Coefficient (MCC): 0.748870730373596
# Cohen's Kappa: 0.745053708745757
# Hamming Loss: 0.12761904761904763
#
# Confusion Matrix:
#  [[5732  486]
#  [1122 5260]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.82      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999657979341952
# Recall: 0.9999661750777973
# F1 Score: 0.9999659853490036
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.9999319730119215
# Cohen's Kappa: 0.9999319706980859
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14781     1]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_13: noncir_mm_scaled_cir_mm_scaled...
# Accuracy: 0.8731746031746032
# Precision: 0.8765900605071946
# Recall: 0.8738040175916928
# F1 Score: 0.8730008905353054
# Mean Squared Error (MSE): 0.1268253968253968
# Matthews Correlation Coefficient (MCC): 0.7503889061085273
# Cohen's Kappa: 0.7466360585052911
# Hamming Loss: 0.1268253968253968
#
# Confusion Matrix:
#  [[5734  484]
#  [1114 5268]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999657979341952
# Recall: 0.9999661750777973
# F1 Score: 0.9999659853490036
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.9999319730119215
# Cohen's Kappa: 0.9999319706980859
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14781     1]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_14: noncir_mm_scaled_cir_ss_scaled...
# Accuracy: 0.8738888888888889
# Precision: 0.8770718261832717
# Recall: 0.8744967275383212
# F1 Score: 0.8737313911484768
# Mean Squared Error (MSE): 0.12611111111111112
# Matthews Correlation Coefficient (MCC): 0.7515641421795851
# Cohen's Kappa: 0.7480520956598176
# Hamming Loss: 0.12611111111111112
#
# Confusion Matrix:
#  [[5728  490]
#  [1099 5283]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_15: noncir_mm_scaled_cir_stats...
# Accuracy: 0.9165079365079365
# Precision: 0.916866407010102
# Recall: 0.9167252219801612
# F1 Score: 0.9165060432209347
# Mean Squared Error (MSE): 0.08349206349206349
# Matthews Correlation Coefficient (MCC): 0.8335916170340414
# Cohen's Kappa: 0.8330648473901987
# Hamming Loss: 0.08349206349206349
#
# Confusion Matrix:
#  [[5804  414]
#  [ 638 5744]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_16: noncir_mm_scaled_cir_stats_mm_scaled...
# Accuracy: 0.9174603174603174
# Precision: 0.9179039927534851
# Recall: 0.9176984279221303
# F1 Score: 0.917456989951724
# Mean Squared Error (MSE): 0.08253968253968254
# Matthews Correlation Coefficient (MCC): 0.8356023953903244
# Cohen's Kappa: 0.834975867487435
# Hamming Loss: 0.08253968253968254
#
# Confusion Matrix:
#  [[5820  398]
#  [ 642 5740]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.94      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_17: noncir_mm_scaled_cir_stats_ss_scaled...
# Accuracy: 0.9169047619047619
# Precision: 0.9172674654169894
# Recall: 0.917123147796568
# F1 Score: 0.9169028142817582
# Mean Squared Error (MSE): 0.0830952380952381
# Matthews Correlation Coefficient (MCC): 0.8343906007328468
# Cohen's Kappa: 0.83385860856528
# Hamming Loss: 0.0830952380952381
#
# Confusion Matrix:
#  [[5807  411]
#  [ 636 5746]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_18: noncir_mm_scaled_cir_stats_trimmed...
# Accuracy: 0.916984126984127
# Precision: 0.9173190913054368
# Recall: 0.9171952940578797
# F1 Score: 0.9169826021747791
# Mean Squared Error (MSE): 0.08301587301587302
# Matthews Correlation Coefficient (MCC): 0.8345143761808752
# Cohen's Kappa: 0.8340148920615704
# Hamming Loss: 0.08301587301587302
#
# Confusion Matrix:
#  [[5804  414]
#  [ 632 5750]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_19: noncir_mm_scaled_cir_stats_mm_scaled_trimmed...
# Accuracy: 0.915079365079365
# Precision: 0.9153980825444761
# Recall: 0.9152860766837899
# F1 Score: 0.9150780278097098
# Mean Squared Error (MSE): 0.08492063492063492
# Matthews Correlation Coefficient (MCC): 0.830684151677073
# Cohen's Kappa: 0.8302050355428391
# Hamming Loss: 0.08492063492063492
#
# Confusion Matrix:
#  [[5790  428]
#  [ 642 5740]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[10:20]
result_view
# Out:
#    Dataset_index                                          Name  \
# 10            10                      noncir_cir_pca_mm_scaled
# 11            11                      noncir_cir_pca_ss_scaled
# 12            12                          noncir_mm_scaled_cir
# 13            13                noncir_mm_scaled_cir_mm_scaled
# 14            14                noncir_mm_scaled_cir_ss_scaled
# 15            15                    noncir_mm_scaled_cir_stats
# 16            16          noncir_mm_scaled_cir_stats_mm_scaled
# 17            17          noncir_mm_scaled_cir_stats_ss_scaled
# 18            18            noncir_mm_scaled_cir_stats_trimmed
# 19            19  noncir_mm_scaled_cir_stats_mm_scaled_trimmed
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 10        1.000000         1.000000       0.902778        0.903779
# 11        1.000000         1.000000       0.902222        0.903390
# 12        0.999966         0.999966       0.872381        0.875860
# 13        0.999966         0.999966       0.873175        0.876590
# 14        1.000000         1.000000       0.873889        0.877072
# 15        1.000000         1.000000       0.916508        0.916866
# 16        1.000000         1.000000       0.917460        0.917904
# 17        1.000000         1.000000       0.916905        0.917267
# 18        1.000000         1.000000       0.916984        0.917319
# 19        1.000000         1.000000       0.915079        0.915398

# %%
# Select the third 10 dataset to be used for Random Forest

for index in range(20, 30):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_20: noncir_mm_scaled_cir_stats_ss_scaled_trimmed...
# Accuracy: 0.9167460317460318
# Precision: 0.9171501150678665
# Recall: 0.9169747225506282
# F1 Score: 0.916743388154571
# Mean Squared Error (MSE): 0.08325396825396826
# Matthews Correlation Coefficient (MCC): 0.8341248191784878
# Cohen's Kappa: 0.8335446799809765
# Hamming Loss: 0.08325396825396826
#
# Confusion Matrix:
#  [[5811  407]
#  [ 642 5740]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_21: noncir_mm_scaled_cir_pca...
# Accuracy: 0.9023015873015873
# Precision: 0.9034353127557667
# Recall: 0.9026662768466999
# F1 Score: 0.9022757189284956
# Mean Squared Error (MSE): 0.0976984126984127
# Matthews Correlation Coefficient (MCC): 0.8061012227651028
# Cohen's Kappa: 0.8047189655798449
# Hamming Loss: 0.0976984126984127
#
# Confusion Matrix:
#  [[5787  431]
#  [ 800 5582]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.87      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_22: noncir_mm_scaled_cir_pca_mm_scaled...
# Accuracy: 0.9026190476190477
# Precision: 0.9036855981925855
# Recall: 0.9029734591468708
# F1 Score: 0.9025957180787348
# Mean Squared Error (MSE): 0.09738095238095239
# Matthews Correlation Coefficient (MCC): 0.8066587429922023
# Cohen's Kappa: 0.8053494908456773
# Hamming Loss: 0.09738095238095239
#
# Confusion Matrix:
#  [[5784  434]
#  [ 793 5589]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_23: noncir_mm_scaled_cir_pca_ss_scaled...
# Accuracy: 0.9025396825396825
# Precision: 0.9035729387831426
# Recall: 0.9028889147156096
# F1 Score: 0.9025175162656663
# Mean Squared Error (MSE): 0.09746031746031746
# Matthews Correlation Coefficient (MCC): 0.8064615634112503
# Cohen's Kappa: 0.8051888402143578
# Hamming Loss: 0.09746031746031746
#
# Confusion Matrix:
#  [[5781  437]
#  [ 791 5591]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_24: noncir_ss_scaled_cir...
# Accuracy: 0.8755555555555555
# Precision: 0.8787614165470052
# Recall: 0.876164709788577
# F1 Score: 0.8753994391208879
# Mean Squared Error (MSE): 0.49777777777777776
# Matthews Correlation Coefficient (MCC): 0.75492166039799
# Cohen's Kappa: 0.7513823167350627
# Hamming Loss: 0.12444444444444444
#
# Confusion Matrix:
#  [[5739  479]
#  [1089 5293]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.88     12600
#    macro avg       0.88      0.88      0.88     12600
# weighted avg       0.88      0.88      0.88     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_25: noncir_ss_scaled_cir_mm_scaled...
# Accuracy: 0.8749206349206349
# Precision: 0.8777746183042767
# Recall: 0.8754966197851206
# F1 Score: 0.8747854543192776
# Mean Squared Error (MSE): 0.5003174603174603
# Matthews Correlation Coefficient (MCC): 0.7532677935870352
# Cohen's Kappa: 0.7500973555141479
# Hamming Loss: 0.12507936507936507
#
# Confusion Matrix:
#  [[5719  499]
#  [1077 5305]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.88      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 0.00013605442176870748
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_26: noncir_ss_scaled_cir_ss_scaled...
# Accuracy: 0.8728571428571429
# Precision: 0.8759775730160165
# Recall: 0.8734596407816734
# F1 Score: 0.8727019091055861
# Mean Squared Error (MSE): 0.5085714285714286
# Matthews Correlation Coefficient (MCC): 0.7494329839566094
# Cohen's Kappa: 0.7459882267559068
# Hamming Loss: 0.12714285714285714
#
# Confusion Matrix:
#  [[5719  499]
#  [1103 5279]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_27: noncir_ss_scaled_cir_stats...
# Accuracy: 0.9171428571428571
# Precision: 0.9176042706798401
# Recall: 0.9173850465369845
# F1 Score: 0.9171391744394989
# Mean Squared Error (MSE): 0.3314285714285714
# Matthews Correlation Coefficient (MCC): 0.834989288438477
# Cohen's Kappa: 0.8343425278284504
# Hamming Loss: 0.08285714285714285
#
# Confusion Matrix:
#  [[5820  398]
#  [ 646 5736]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.94      0.92      6218
#          1.0       0.94      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_28: noncir_ss_scaled_cir_stats_mm_scaled...
# Accuracy: 0.9165079365079365
# Precision: 0.9170343137254902
# Recall: 0.9167644828516678
# F1 Score: 0.9165028854479204
# Mean Squared Error (MSE): 0.33396825396825397
# Matthews Correlation Coefficient (MCC): 0.8337987529163235
# Cohen's Kappa: 0.833077948336673
# Hamming Loss: 0.08349206349206349
#
# Confusion Matrix:
#  [[5823  395]
#  [ 657 5725]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.94      0.92      6218
#          1.0       0.94      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_29: noncir_ss_scaled_cir_stats_ss_scaled...
# Accuracy: 0.9169047619047619
# Precision: 0.9172920962920075
# Recall: 0.9171293468815427
# F1 Score: 0.916902412288541
# Mean Squared Error (MSE): 0.3323809523809524
# Matthews Correlation Coefficient (MCC): 0.8344214273018519
# Cohen's Kappa: 0.8338606674317288
# Hamming Loss: 0.0830952380952381
#
# Confusion Matrix:
#  [[5810  408]
#  [ 639 5743]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[20:30]
result_view
# Out:
#    Dataset_index                                          Name  \
# 20            20  noncir_mm_scaled_cir_stats_ss_scaled_trimmed
# 21            21                      noncir_mm_scaled_cir_pca
# 22            22            noncir_mm_scaled_cir_pca_mm_scaled
# 23            23            noncir_mm_scaled_cir_pca_ss_scaled
# 24            24                          noncir_ss_scaled_cir
# 25            25                noncir_ss_scaled_cir_mm_scaled
# 26            26                noncir_ss_scaled_cir_ss_scaled
# 27            27                    noncir_ss_scaled_cir_stats
# 28            28          noncir_ss_scaled_cir_stats_mm_scaled
# 29            29          noncir_ss_scaled_cir_stats_ss_scaled
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 20        0.999966         0.999966       0.916746        0.917150
# 21        1.000000         1.000000       0.902302        0.903435
# 22        0.999966         0.999966       0.902619        0.903686
# 23        1.000000         1.000000       0.902540        0.903573
# 24        1.000000         1.000000       0.875556        0.878761
# 25        0.999966         0.999966       0.874921        0.877775
# 26        1.000000         1.000000       0.872857        0.875978
# 27        1.000000         1.000000       0.917143        0.917604
# 28        1.000000         1.000000       0.916508        0.917034
# 29        1.000000         1.000000       0.916905        0.917292

# %%
# Select the fourth 10 dataset to be used for Random Forest

for index in range(30, 40):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_30: noncir_ss_scaled_cir_stats_trimmed...
# Accuracy: 0.9162698412698412
# Precision: 0.9166568203090875
# Recall: 0.9164943186646184
# F1 Score: 0.9162674737004878
# Mean Squared Error (MSE): 0.3349206349206349
# Matthews Correlation Coefficient (MCC): 0.8331511231261701
# Cohen's Kappa: 0.8325912169441012
# Hamming Loss: 0.08373015873015872
#
# Confusion Matrix:
#  [[5806  412]
#  [ 643 5739]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 0.00013605442176870748
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_31: noncir_ss_scaled_cir_stats_mm_scaled_trimmed...
# Accuracy: 0.9173809523809524
# Precision: 0.9178562204966896
# Recall: 0.9176262816608185
# F1 Score: 0.9173770132691701
# Mean Squared Error (MSE): 0.3304761904761905
# Matthews Correlation Coefficient (MCC): 0.8354824705159901
# Cohen's Kappa: 0.8348195784903321
# Hamming Loss: 0.08261904761904762
#
# Confusion Matrix:
#  [[5823  395]
#  [ 646 5736]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.94      0.92      6218
#          1.0       0.94      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_32: noncir_ss_scaled_cir_stats_ss_scaled_trimmed...
# Accuracy: 0.9158730158730158
# Precision: 0.9163156409090455
# Recall: 0.9161108573798191
# F1 Score: 0.9158696243738724
# Mean Squared Error (MSE): 0.33650793650793653
# Matthews Correlation Coefficient (MCC): 0.8324264730996771
# Cohen's Kappa: 0.831802326477578
# Hamming Loss: 0.08412698412698413
#
# Confusion Matrix:
#  [[5810  408]
#  [ 652 5730]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_33: noncir_ss_scaled_cir_pca...
# Accuracy: 0.9033333333333333
# Precision: 0.9043549376405643
# Recall: 0.903680633625107
# F1 Score: 0.9033118080911136
# Mean Squared Error (MSE): 0.38666666666666666
# Matthews Correlation Coefficient (MCC): 0.8080352899129681
# Cohen's Kappa: 0.8067744523463102
# Hamming Loss: 0.09666666666666666
#
# Confusion Matrix:
#  [[5785  433]
#  [ 785 5597]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_34: noncir_ss_scaled_cir_pca_mm_scaled...
# Accuracy: 0.903015873015873
# Precision: 0.9040765163191515
# Recall: 0.9033693186016194
# F1 Score: 0.9029928762905775
# Mean Squared Error (MSE): 0.3879365079365079
# Matthews Correlation Coefficient (MCC): 0.8074455252227791
# Cohen's Kappa: 0.806142287421292
# Hamming Loss: 0.09698412698412698
#
# Confusion Matrix:
#  [[5786  432]
#  [ 790 5592]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_35: noncir_ss_scaled_cir_pca_ss_scaled...
# Accuracy: 0.9029365079365079
# Precision: 0.9037763349284197
# Recall: 0.9032537787454846
# F1 Score: 0.9029210490491372
# Mean Squared Error (MSE): 0.38825396825396824
# Matthews Correlation Coefficient (MCC): 0.8070299444949677
# Cohen's Kappa: 0.8059696253027152
# Hamming Loss: 0.09706349206349206
#
# Confusion Matrix:
#  [[5768  450]
#  [ 773 5609]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_36: noncir_trimmed_cir...
# Accuracy: 0.8717460317460317
# Precision: 0.874750075175277
# Recall: 0.8723380095937644
# F1 Score: 0.8715964864597279
# Mean Squared Error (MSE): 0.12825396825396826
# Matthews Correlation Coefficient (MCC): 0.747084190933997
# Cohen's Kappa: 0.7437631103445526
# Hamming Loss: 0.12825396825396826
#
# Confusion Matrix:
#  [[5707  511]
#  [1105 5277]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.87      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_37: noncir_trimmed_cir_mm_scaled...
# Accuracy: 0.8751587301587301
# Precision: 0.8782181382138516
# Recall: 0.8757543858022205
# F1 Score: 0.8750111234601059
# Mean Squared Error (MSE): 0.12484126984126984
# Matthews Correlation Coefficient (MCC): 0.7539684986093389
# Cohen's Kappa: 0.7505828391711212
# Hamming Loss: 0.12484126984126984
#
# Confusion Matrix:
#  [[5730  488]
#  [1085 5297]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.88     12600
#    macro avg       0.88      0.88      0.88     12600
# weighted avg       0.88      0.88      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_38: noncir_trimmed_cir_ss_scaled...
# Accuracy: 0.8730952380952381
# Precision: 0.8762504162504162
# Recall: 0.8737008759055074
# F1 Score: 0.8729381723569343
# Mean Squared Error (MSE): 0.1269047619047619
# Matthews Correlation Coefficient (MCC): 0.7499469584246404
# Cohen's Kappa: 0.7464654739568193
# Hamming Loss: 0.1269047619047619
#
# Confusion Matrix:
#  [[5722  496]
#  [1103 5279]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_39: noncir_trimmed_cir_stats...
# Accuracy: 0.9161111111111111
# Precision: 0.9166713928429409
# Recall: 0.916374822481894
# F1 Score: 0.9161052850892423
# Mean Squared Error (MSE): 0.08388888888888889
# Matthews Correlation Coefficient (MCC): 0.8330461625342571
# Cohen's Kappa: 0.8322870171549244
# Hamming Loss: 0.08388888888888889
#
# Confusion Matrix:
#  [[5824  394]
#  [ 663 5719]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.94      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[30:40]
result_view
# Out:
#    Dataset_index                                          Name  \
# 30            30            noncir_ss_scaled_cir_stats_trimmed
# 31            31  noncir_ss_scaled_cir_stats_mm_scaled_trimmed
# 32            32  noncir_ss_scaled_cir_stats_ss_scaled_trimmed
# 33            33                      noncir_ss_scaled_cir_pca
# 34            34            noncir_ss_scaled_cir_pca_mm_scaled
# 35            35            noncir_ss_scaled_cir_pca_ss_scaled
# 36            36                            noncir_trimmed_cir
# 37            37                  noncir_trimmed_cir_mm_scaled
# 38            38                  noncir_trimmed_cir_ss_scaled
# 39            39                      noncir_trimmed_cir_stats
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 30        0.999966         0.999966       0.916270        0.916657
# 31        1.000000         1.000000       0.917381        0.917856
# 32        1.000000         1.000000       0.915873        0.916316
# 33        1.000000         1.000000       0.903333        0.904355
# 34        1.000000         1.000000       0.903016        0.904077
# 35        1.000000         1.000000       0.902937        0.903776
# 36        1.000000         1.000000       0.871746        0.874750
# 37        1.000000         1.000000       0.875159        0.878218
# 38        1.000000         1.000000       0.873095        0.876250
# 39        1.000000         1.000000       0.916111        0.916671

# %%
# Select the fifth 10 dataset to be used for Random Forest

for index in range(40, 50):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_40: noncir_trimmed_cir_stats_mm_scaled...
# Accuracy: 0.9165079365079365
# Precision: 0.9169599030877664
# Recall: 0.9167479519584019
# F1 Score: 0.9165044001989603
# Mean Squared Error (MSE): 0.08349206349206349
# Matthews Correlation Coefficient (MCC): 0.8337078281043074
# Cohen's Kappa: 0.8330724323993222
# Hamming Loss: 0.08349206349206349
#
# Confusion Matrix:
#  [[5815  403]
#  [ 649 5733]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_41: noncir_trimmed_cir_stats_ss_scaled...
# Accuracy: 0.9146825396825397
# Precision: 0.9152515041314961
# Recall: 0.9149480753554722
# F1 Score: 0.9146763865580103
# Mean Squared Error (MSE): 0.08531746031746032
# Matthews Correlation Coefficient (MCC): 0.8301995240370335
# Cohen's Kappa: 0.8294316822320174
# Hamming Loss: 0.08531746031746032
#
# Confusion Matrix:
#  [[5816  402]
#  [ 673 5709]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.93      0.89      0.91      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.92      0.91      0.91     12600
# weighted avg       0.92      0.91      0.91     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_42: noncir_trimmed_cir_stats_trimmed...
# Accuracy: 0.9141269841269841
# Precision: 0.9146044865119727
# Recall: 0.91437279522991
# F1 Score: 0.9141227952061355
# Mean Squared Error (MSE): 0.08587301587301588
# Matthews Correlation Coefficient (MCC): 0.8289772493641248
# Cohen's Kappa: 0.8283142680550091
# Hamming Loss: 0.08587301587301588
#
# Confusion Matrix:
#  [[5803  415]
#  [ 667 5715]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.91      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.91      0.91      0.91     12600
# weighted avg       0.91      0.91      0.91     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_43: noncir_trimmed_cir_stats_mm_scaled_trimmed...
# Accuracy: 0.9168253968253969
# Precision: 0.9172865898026858
# Recall: 0.9170675324285222
# F1 Score: 0.916821700012064
# Mean Squared Error (MSE): 0.08317460317460318
# Matthews Correlation Coefficient (MCC): 0.8343540934747529
# Cohen's Kappa: 0.8337078248699388
# Hamming Loss: 0.08317460317460318
#
# Confusion Matrix:
#  [[5818  400]
#  [ 648 5734]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_44: noncir_trimmed_cir_stats_ss_scaled_trimmed...
# Accuracy: 0.915
# Precision: 0.9155013789299504
# Recall: 0.9152511249323266
# F1 Score: 0.9149953690787803
# Mean Squared Error (MSE): 0.085
# Matthews Correlation Coefficient (MCC): 0.8307524661693032
# Cohen's Kappa: 0.830061441630451
# Hamming Loss: 0.085
#
# Confusion Matrix:
#  [[5811  407]
#  [ 664 5718]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.91     12600
# weighted avg       0.92      0.92      0.91     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_45: noncir_trimmed_cir_pca...
# Accuracy: 0.9057142857142857
# Precision: 0.906675516879341
# Recall: 0.9060516576302824
# F1 Score: 0.9056954651997946
# Mean Squared Error (MSE): 0.09428571428571429
# Matthews Correlation Coefficient (MCC): 0.8127269350686201
# Cohen's Kappa: 0.8115298106434135
# Hamming Loss: 0.09428571428571429
#
# Confusion Matrix:
#  [[5795  423]
#  [ 765 5617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.91      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.91      0.91      0.91     12600
# weighted avg       0.91      0.91      0.91     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_46: noncir_trimmed_cir_pca_mm_scaled...
# Accuracy: 0.9073809523809524
# Precision: 0.9081916700675101
# Recall: 0.9076927771789809
# F1 Score: 0.9073672937829438
# Mean Squared Error (MSE): 0.09261904761904761
# Matthews Correlation Coefficient (MCC): 0.8158842947162287
# Cohen's Kappa: 0.814851796570423
# Hamming Loss: 0.09261904761904761
#
# Confusion Matrix:
#  [[5793  425]
#  [ 742 5640]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.93      0.91      6218
#          1.0       0.93      0.88      0.91      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.91      0.91      0.91     12600
# weighted avg       0.91      0.91      0.91     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_47: noncir_trimmed_cir_pca_ss_scaled...
# Accuracy: 0.9036507936507937
# Precision: 0.9043711656441717
# Recall: 0.903946488692113
# F1 Score: 0.9036392347290638
# Mean Squared Error (MSE): 0.09634920634920635
# Matthews Correlation Coefficient (MCC): 0.8083175427770946
# Cohen's Kappa: 0.8073891332838388
# Hamming Loss: 0.09634920634920635
#
# Confusion Matrix:
#  [[5762  456]
#  [ 758 5624]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_48: noncir_mm_scaled_trimmed_cir...
# Accuracy: 0.8718253968253968
# Precision: 0.8746915487612268
# Recall: 0.8724039567701014
# F1 Score: 0.8716848539151074
# Mean Squared Error (MSE): 0.12817460317460316
# Matthews Correlation Coefficient (MCC): 0.7470920032418986
# Cohen's Kappa: 0.7439148020692601
# Hamming Loss: 0.12817460317460316
#
# Confusion Matrix:
#  [[5701  517]
#  [1098 5284]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.87      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_49: noncir_mm_scaled_trimmed_cir_mm_scaled...
# Accuracy: 0.8732539682539683
# Precision: 0.8767511659839304
# Recall: 0.8738906283846122
# F1 Score: 0.873075102163845
# Mean Squared Error (MSE): 0.12674603174603175
# Matthews Correlation Coefficient (MCC): 0.750636343895943
# Cohen's Kappa: 0.7467982668399122
# Hamming Loss: 0.12674603174603175
#
# Confusion Matrix:
#  [[5738  480]
#  [1117 5265]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.82      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[40:50]
result_view
# Out:
#    Dataset_index                                        Name  Train_Accuracy  \
# 40            40          noncir_trimmed_cir_stats_mm_scaled        1.000000
# 41            41          noncir_trimmed_cir_stats_ss_scaled        0.999966
# 42            42            noncir_trimmed_cir_stats_trimmed        0.999966
# 43            43  noncir_trimmed_cir_stats_mm_scaled_trimmed        1.000000
# 44            44  noncir_trimmed_cir_stats_ss_scaled_trimmed        1.000000
# 45            45                      noncir_trimmed_cir_pca        1.000000
# 46            46            noncir_trimmed_cir_pca_mm_scaled        1.000000
# 47            47            noncir_trimmed_cir_pca_ss_scaled        1.000000
# 48            48                noncir_mm_scaled_trimmed_cir        1.000000
# 49            49      noncir_mm_scaled_trimmed_cir_mm_scaled        1.000000
#
#     Train_Precision  Test_Accuracy  Test_Precision
# 40         1.000000       0.916508        0.916960
# 41         0.999966       0.914683        0.915252
# 42         0.999966       0.914127        0.914604
# 43         1.000000       0.916825        0.917287
# 44         1.000000       0.915000        0.915501
# 45         1.000000       0.905714        0.906676
# 46         1.000000       0.907381        0.908192
# 47         1.000000       0.903651        0.904371
# 48         1.000000       0.871825        0.874692
# 49         1.000000       0.873254        0.876751

# %%
# Select the fifth 10 dataset to be used for Random Forest

for index in range(50, 60):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_50: noncir_mm_scaled_trimmed_cir_ss_scaled...
# Accuracy: 0.8716666666666667
# Precision: 0.8747460562473379
# Recall: 0.8722658633324527
# F1 Score: 0.8715121113403285
# Mean Squared Error (MSE): 0.12833333333333333
# Matthews Correlation Coefficient (MCC): 0.7470078022600489
# Cohen's Kappa: 0.7436082519529701
# Hamming Loss: 0.12833333333333333
#
# Confusion Matrix:
#  [[5710  508]
#  [1109 5273]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.87      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_51: noncir_mm_scaled_trimmed_cir_stats...
# Accuracy: 0.9153174603174603
# Precision: 0.9158869967097372
# Recall: 0.9155831035723966
# F1 Score: 0.915311352983625
# Mean Squared Error (MSE): 0.08468253968253968
# Matthews Correlation Coefficient (MCC): 0.8314700447473394
# Cohen's Kappa: 0.8307010278526163
# Hamming Loss: 0.08468253968253968
#
# Confusion Matrix:
#  [[5820  398]
#  [ 669 5713]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_52: noncir_mm_scaled_trimmed_cir_stats_mm_scaled...
# Accuracy: 0.915
# Precision: 0.9154288600910043
# Recall: 0.9152345940390607
# F1 Score: 0.9149968254987301
# Mean Squared Error (MSE): 0.085
# Matthews Correlation Coefficient (MCC): 0.8306634314137054
# Cohen's Kappa: 0.8300558259546789
# Hamming Loss: 0.085
#
# Confusion Matrix:
#  [[5803  415]
#  [ 656 5726]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.91     12600
# weighted avg       0.92      0.92      0.91     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_53: noncir_mm_scaled_trimmed_cir_stats_ss_scaled...
# Accuracy: 0.915079365079365
# Precision: 0.9156045751633988
# Recall: 0.9153356693635879
# F1 Score: 0.9150742275943677
# Mean Squared Error (MSE): 0.08492063492063492
# Matthews Correlation Coefficient (MCC): 0.8309402010158365
# Cohen's Kappa: 0.830221867604791
# Hamming Loss: 0.08492063492063492
#
# Confusion Matrix:
#  [[5814  404]
#  [ 666 5716]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.94      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_54: noncir_mm_scaled_trimmed_cir_stats_trimmed...
# Accuracy: 0.9153174603174603
# Precision: 0.9157292238499117
# Recall: 0.9155479754242064
# F1 Score: 0.9153146177349327
# Mean Squared Error (MSE): 0.08468253968253968
# Matthews Correlation Coefficient (MCC): 0.8312771795147693
# Cohen's Kappa: 0.8306891393559784
# Hamming Loss: 0.08468253968253968
#
# Confusion Matrix:
#  [[5803  415]
#  [ 652 5730]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_55: noncir_mm_scaled_trimmed_cir_stats_mm_scaled_trimmed...
# Accuracy: 0.9161111111111111
# Precision: 0.9165672976739525
# Recall: 0.9163520925036531
# F1 Score: 0.9161074708009974
# Mean Squared Error (MSE): 0.08388888888888889
# Matthews Correlation Coefficient (MCC): 0.832919362375836
# Cohen's Kappa: 0.832279396819376
# Hamming Loss: 0.08388888888888889
#
# Confusion Matrix:
#  [[5813  405]
#  [ 652 5730]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_56: noncir_mm_scaled_trimmed_cir_stats_ss_scaled_trimmed...
# Accuracy: 0.9164285714285715
# Precision: 0.9168671356266711
# Recall: 0.9166654738887989
# F1 Score: 0.91642528603055
# Mean Squared Error (MSE): 0.08357142857142857
# Matthews Correlation Coefficient (MCC): 0.8335325851208293
# Cohen's Kappa: 0.8329127207422716
# Hamming Loss: 0.08357142857142857
#
# Confusion Matrix:
#  [[5813  405]
#  [ 648 5734]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_57: noncir_mm_scaled_trimmed_cir_pca...
# Accuracy: 0.9043650793650794
# Precision: 0.9051833142246581
# Recall: 0.9046784595102482
# F1 Score: 0.9043506048329624
# Mean Squared Error (MSE): 0.09563492063492063
# Matthews Correlation Coefficient (MCC): 0.8098616163757645
# Cohen's Kappa: 0.8088237671682754
# Hamming Loss: 0.09563492063492063
#
# Confusion Matrix:
#  [[5775  443]
#  [ 762 5620]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.91      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.91      0.90      0.90     12600
# weighted avg       0.91      0.90      0.90     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999657979341952
# Recall: 0.9999661750777973
# F1 Score: 0.9999659853490036
# Mean Squared Error (MSE): 3.401360544217687e-05
# Matthews Correlation Coefficient (MCC): 0.9999319730119215
# Cohen's Kappa: 0.9999319706980859
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14781     1]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_58: noncir_mm_scaled_trimmed_cir_pca_mm_scaled...
# Accuracy: 0.9038888888888889
# Precision: 0.904815523542917
# Recall: 0.904220785602479
# F1 Score: 0.9038707668693728
# Mean Squared Error (MSE): 0.0961111111111111
# Matthews Correlation Coefficient (MCC): 0.8090360905437946
# Cohen's Kappa: 0.8078789934554509
# Hamming Loss: 0.0961111111111111
#
# Confusion Matrix:
#  [[5781  437]
#  [ 774 5608]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.91      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.91      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_59: noncir_mm_scaled_trimmed_cir_pca_ss_scaled...
# Accuracy: 0.905079365079365
# Precision: 0.9059769099741342
# Recall: 0.9054062976050666
# F1 Score: 0.9050624872993294
# Mean Squared Error (MSE): 0.09492063492063492
# Matthews Correlation Coefficient (MCC): 0.8113830069350951
# Cohen's Kappa: 0.8102567331058537
# Hamming Loss: 0.09492063492063492
#
# Confusion Matrix:
#  [[5786  432]
#  [ 764 5618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.91      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.91      0.91      0.91     12600
# weighted avg       0.91      0.91      0.91     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[50:60]
result_view
# Out:
#    Dataset_index                                               Name  \
# 50            50             noncir_mm_scaled_trimmed_cir_ss_scaled
# 51            51                 noncir_mm_scaled_trimmed_cir_stats
# 52            52       noncir_mm_scaled_trimmed_cir_stats_mm_scaled
# 53            53       noncir_mm_scaled_trimmed_cir_stats_ss_scaled
# 54            54         noncir_mm_scaled_trimmed_cir_stats_trimmed
# 55            55  noncir_mm_scaled_trimmed_cir_stats_mm_scaled_t...
# 56            56  noncir_mm_scaled_trimmed_cir_stats_ss_scaled_t...
# 57            57                   noncir_mm_scaled_trimmed_cir_pca
# 58            58         noncir_mm_scaled_trimmed_cir_pca_mm_scaled
# 59            59         noncir_mm_scaled_trimmed_cir_pca_ss_scaled
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 50        1.000000         1.000000       0.871667        0.874746
# 51        1.000000         1.000000       0.915317        0.915887
# 52        1.000000         1.000000       0.915000        0.915429
# 53        1.000000         1.000000       0.915079        0.915605
# 54        1.000000         1.000000       0.915317        0.915729
# 55        1.000000         1.000000       0.916111        0.916567
# 56        1.000000         1.000000       0.916429        0.916867
# 57        0.999966         0.999966       0.904365        0.905183
# 58        1.000000         1.000000       0.903889        0.904816
# 59        1.000000         1.000000       0.905079        0.905977

# %%
# Select the sixth 10 dataset to be used for Random Forest

for index in range(60, 70):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_60: noncir_ss_scaled_trimmed_cir...
# Accuracy: 0.8751587301587301
# Precision: 0.8785316878211737
# Recall: 0.875783314865436
# F1 Score: 0.8749913898031769
# Mean Squared Error (MSE): 0.49936507936507935
# Matthews Correlation Coefficient (MCC): 0.754309995773751
# Cohen's Kappa: 0.7505972513677399
# Hamming Loss: 0.12484126984126984
#
# Confusion Matrix:
#  [[5744  474]
#  [1099 5283]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.84      0.92      0.88      6218
#          1.0       0.92      0.83      0.87      6382
#
#     accuracy                           0.88     12600
#    macro avg       0.88      0.88      0.87     12600
# weighted avg       0.88      0.88      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_61: noncir_ss_scaled_trimmed_cir_mm_scaled...
# Accuracy: 0.871031746031746
# Precision: 0.8740202961387769
# Recall: 0.8716225696688953
# F1 Score: 0.8708820673126121
# Mean Squared Error (MSE): 0.5158730158730159
# Matthews Correlation Coefficient (MCC): 0.7456390106731633
# Cohen's Kappa: 0.7423355166837973
# Hamming Loss: 0.12896825396825398
#
# Confusion Matrix:
#  [[5702  516]
#  [1109 5273]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.87      0.87      0.87     12600
# weighted avg       0.87      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_62: noncir_ss_scaled_trimmed_cir_ss_scaled...
# Accuracy: 0.8738888888888889
# Precision: 0.8770054354346134
# Recall: 0.8744905284533464
# F1 Score: 0.8737356147733354
# Mean Squared Error (MSE): 0.5044444444444445
# Matthews Correlation Coefficient (MCC): 0.7514917557650047
# Cohen's Kappa: 0.748048975854209
# Hamming Loss: 0.12611111111111112
#
# Confusion Matrix:
#  [[5725  493]
#  [1096 5286]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.84      0.92      0.88      6218
#          1.0       0.91      0.83      0.87      6382
#
#     accuracy                           0.87     12600
#    macro avg       0.88      0.87      0.87     12600
# weighted avg       0.88      0.87      0.87     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_63: noncir_ss_scaled_trimmed_cir_stats...
# Accuracy: 0.915079365079365
# Precision: 0.9155126511430906
# Recall: 0.9153150057470054
# F1 Score: 0.9150761106264617
# Mean Squared Error (MSE): 0.3396825396825397
# Matthews Correlation Coefficient (MCC): 0.830827633381187
# Cohen's Kappa: 0.8302148546512214
# Hamming Loss: 0.08492063492063492
#
# Confusion Matrix:
#  [[5804  414]
#  [ 656 5726]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 0.00013605442176870748
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_64: noncir_ss_scaled_trimmed_cir_stats_mm_scaled...
# Accuracy: 0.9136507936507936
# Precision: 0.9142138567536684
# Recall: 0.9139151213221408
# F1 Score: 0.9136446819831618
# Mean Squared Error (MSE): 0.3453968253968254
# Matthews Correlation Coefficient (MCC): 0.828128924193586
# Cohen's Kappa: 0.8273686390793639
# Hamming Loss: 0.08634920634920636
#
# Confusion Matrix:
#  [[5809  409]
#  [ 679 5703]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.91      6218
#          1.0       0.93      0.89      0.91      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.91      0.91      0.91     12600
# weighted avg       0.91      0.91      0.91     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_65: noncir_ss_scaled_trimmed_cir_stats_ss_scaled...
# Accuracy: 0.9153968253968254
# Precision: 0.9159222948438634
# Recall: 0.91565318347205
# F1 Score: 0.9153917071173794
# Mean Squared Error (MSE): 0.3384126984126984
# Matthews Correlation Coefficient (MCC): 0.8315754347715003
# Cohen's Kappa: 0.8308565522118758
# Hamming Loss: 0.0846031746031746
#
# Confusion Matrix:
#  [[5816  402]
#  [ 664 5718]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.94      0.92      6218
#          1.0       0.93      0.90      0.91      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 0.00013605442176870748
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_66: noncir_ss_scaled_trimmed_cir_stats_trimmed...
# Accuracy: 0.9155555555555556
# Precision: 0.9159979705401576
# Recall: 0.915793343271357
# F1 Score: 0.9155521512583022
# Mean Squared Error (MSE): 0.3377777777777778
# Matthews Correlation Coefficient (MCC): 0.8317912886415476
# Cohen's Kappa: 0.8311676182756067
# Hamming Loss: 0.08444444444444445
#
# Confusion Matrix:
#  [[5808  410]
#  [ 654 5728]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_67: noncir_ss_scaled_trimmed_cir_stats_mm_scaled_trimmed...
# Accuracy: 0.9167460317460318
# Precision: 0.9172487589630447
# Recall: 0.9169974525288689
# F1 Score: 0.9167414959511115
# Mean Squared Error (MSE): 0.33301587301587304
# Matthews Correlation Coefficient (MCC): 0.834246173640423
# Cohen's Kappa: 0.8335522430161935
# Hamming Loss: 0.08325396825396826
#
# Confusion Matrix:
#  [[5822  396]
#  [ 653 5729]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.94      0.92      6218
#          1.0       0.94      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 0.00013605442176870748
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_68: noncir_ss_scaled_trimmed_cir_stats_ss_scaled_trimmed...
# Accuracy: 0.9157936507936508
# Precision: 0.9162586555213867
# Recall: 0.9160366447568492
# F1 Score: 0.9157898184771889
# Mean Squared Error (MSE): 0.3368253968253968
# Matthews Correlation Coefficient (MCC): 0.832295270668084
# Cohen's Kappa: 0.8316453879581078
# Hamming Loss: 0.0842063492063492
#
# Confusion Matrix:
#  [[5812  406]
#  [ 655 5727]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.90      0.93      0.92      6218
#          1.0       0.93      0.90      0.92      6382
#
#     accuracy                           0.92     12600
#    macro avg       0.92      0.92      0.92     12600
# weighted avg       0.92      0.92      0.92     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_69: noncir_ss_scaled_trimmed_cir_pca...
# Accuracy: 0.9037301587301587
# Precision: 0.9045951328508282
# Recall: 0.9040516967399567
# F1 Score: 0.9037140449638489
# Mean Squared Error (MSE): 0.3850793650793651
# Matthews Correlation Coefficient (MCC): 0.8086466469876823
# Cohen's Kappa: 0.8075577265123297
# Hamming Loss: 0.09626984126984127
#
# Confusion Matrix:
#  [[5775  443]
#  [ 770 5612]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.88      0.93      0.90      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.90      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[60:70]
result_view
# Out:
#    Dataset_index                                               Name  \
# 60            60                       noncir_ss_scaled_trimmed_cir
# 61            61             noncir_ss_scaled_trimmed_cir_mm_scaled
# 62            62             noncir_ss_scaled_trimmed_cir_ss_scaled
# 63            63                 noncir_ss_scaled_trimmed_cir_stats
# 64            64       noncir_ss_scaled_trimmed_cir_stats_mm_scaled
# 65            65       noncir_ss_scaled_trimmed_cir_stats_ss_scaled
# 66            66         noncir_ss_scaled_trimmed_cir_stats_trimmed
# 67            67  noncir_ss_scaled_trimmed_cir_stats_mm_scaled_t...
# 68            68  noncir_ss_scaled_trimmed_cir_stats_ss_scaled_t...
# 69            69                   noncir_ss_scaled_trimmed_cir_pca
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 60        1.000000         1.000000       0.875159        0.878532
# 61        1.000000         1.000000       0.871032        0.874020
# 62        1.000000         1.000000       0.873889        0.877005
# 63        0.999966         0.999966       0.915079        0.915513
# 64        1.000000         1.000000       0.913651        0.914214
# 65        0.999966         0.999966       0.915397        0.915922
# 66        1.000000         1.000000       0.915556        0.915998
# 67        0.999966         0.999966       0.916746        0.917249
# 68        1.000000         1.000000       0.915794        0.916259
# 69        1.000000         1.000000       0.903730        0.904595

# %%
# Select the sixth 10 dataset to be used for Random Forest

for index in range(70, 72):
    data = globals()[f"dataset_{index}"] 
    
    name_value = result_df.loc[index, 'Name'] if index < len(result_df) else None
    print(f"Evaluating dataset_{index}: {name_value}...")

    # Define features and target variable
    X = data.drop('NLOS', axis=1)
    y = data['NLOS']

    # Split data into train and test sets (70:30)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

    # Train Random Forest classifier
    rf_classifier = RandomForestClassifier()
    rf_classifier.fit(X_train, y_train)

    """ Random Forest Model Performance """
    y_test_pred = rf_classifier.predict(X_test)
    y_train_pred = rf_classifier.predict(X_train)

    results_test = classifier_metrics(list(y_test), y_test_pred, print_results=True)
    results_train = classifier_metrics(list(y_train), y_train_pred, print_results=True)

    # Append the performance metrics to result_df with the same index
    result_df.loc[index, 'Train_Accuracy'] = results_train["accuracy"]
    result_df.loc[index, 'Train_Precision'] = results_train['precision']
    result_df.loc[index, 'Test_Accuracy'] = results_test["accuracy"]
    result_df.loc[index, 'Test_Precision'] = results_test['precision']

    # Export model
    save_to_pickle(f'{MODEL_FOLDER}/Random_Forest/rf_{name_value}.pkl', rf_classifier, complete_path=False)
# Out:
# Evaluating dataset_70: noncir_ss_scaled_trimmed_cir_pca_mm_scaled...
# Accuracy: 0.9058730158730158
# Precision: 0.9068473072955908
# Recall: 0.9062124810461717
# F1 Score: 0.905853802363294
# Mean Squared Error (MSE): 0.3765079365079365
# Matthews Correlation Coefficient (MCC): 0.8130595405097861
# Cohen's Kappa: 0.8118478775560238
# Hamming Loss: 0.09412698412698413
#
# Confusion Matrix:
#  [[5797  421]
#  [ 765 5617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.88      0.93      0.91      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.91     12600
#    macro avg       0.91      0.91      0.91     12600
# weighted avg       0.91      0.91      0.91     12600
#
#
#
# Accuracy: 0.9999659863945578
# Precision: 0.9999661773658932
# Recall: 0.9999657955944725
# F1 Score: 0.9999659853231876
# Mean Squared Error (MSE): 0.00013605442176870748
# Matthews Correlation Coefficient (MCC): 0.999931972960293
# Cohen's Kappa: 0.9999319706464539
# Hamming Loss: 3.401360544217687e-05
#
# Confusion Matrix:
#  [[14782     0]
#  [    1 14617]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400
#
#
#
# Evaluating dataset_71: noncir_ss_scaled_trimmed_cir_pca_ss_scaled...
# Accuracy: 0.9038095238095238
# Precision: 0.9047675052495558
# Recall: 0.9041465729795091
# F1 Score: 0.9037903230826188
# Mean Squared Error (MSE): 0.38476190476190475
# Matthews Correlation Coefficient (MCC): 0.8089138399114542
# Cohen's Kappa: 0.8077223320705532
# Hamming Loss: 0.09619047619047619
#
# Confusion Matrix:
#  [[5783  435]
#  [ 777 5605]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       0.88      0.93      0.91      6218
#          1.0       0.93      0.88      0.90      6382
#
#     accuracy                           0.90     12600
#    macro avg       0.90      0.90      0.90     12600
# weighted avg       0.91      0.90      0.90     12600
#
#
#
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Mean Squared Error (MSE): 0.0
# Matthews Correlation Coefficient (MCC): 1.0
# Cohen's Kappa: 1.0
# Hamming Loss: 0.0
#
# Confusion Matrix:
#  [[14782     0]
#  [    0 14618]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#         -1.0       1.00      1.00      1.00     14782
#          1.0       1.00      1.00      1.00     14618
#
#     accuracy                           1.00     29400
#    macro avg       1.00      1.00      1.00     29400
# weighted avg       1.00      1.00      1.00     29400

# %%
result_view = result_df.iloc[70:72]
result_view
# Out:
#    Dataset_index                                        Name  Train_Accuracy  \
# 70            70  noncir_ss_scaled_trimmed_cir_pca_mm_scaled        0.999966
# 71            71  noncir_ss_scaled_trimmed_cir_pca_ss_scaled        1.000000
#
#     Train_Precision  Test_Accuracy  Test_Precision
# 70         0.999966       0.905873        0.906847
# 71         1.000000       0.903810        0.904768

# %%
result_df
# Out:
#    Dataset_index                                               Name  \
# 0              0                                         noncir_cir
# 1              1                               noncir_cir_mm_scaled
# 2              2                               noncir_cir_ss_scaled
# 3              3                                   noncir_cir_stats
# 4              4                         noncir_cir_stats_mm_scaled
# ..           ...                                                ...
# 67            67  noncir_ss_scaled_trimmed_cir_stats_mm_scaled_t...
# 68            68  noncir_ss_scaled_trimmed_cir_stats_ss_scaled_t...
# 69            69                   noncir_ss_scaled_trimmed_cir_pca
# 70            70         noncir_ss_scaled_trimmed_cir_pca_mm_scaled
# 71            71         noncir_ss_scaled_trimmed_cir_pca_ss_scaled
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 0         1.000000         1.000000       0.874921        0.877968
# 1         1.000000         1.000000       0.874048        0.877321
# 2         1.000000         1.000000       0.872778        0.876202
# 3         1.000000         1.000000       0.917063        0.917468
# 4         0.999966         0.999966       0.915079        0.915462
# ..             ...              ...            ...             ...
# 67        0.999966         0.999966       0.916746        0.917249
# 68        1.000000         1.000000       0.915794        0.916259
# 69        1.000000         1.000000       0.903730        0.904595
# 70        0.999966         0.999966       0.905873        0.906847
# 71        1.000000         1.000000       0.903810        0.904768
#
# [72 rows x 6 columns]

# %%
highest_accuracy_index = result_df['Test_Accuracy'].idxmax()
row_highest_accuracy = result_df.loc[highest_accuracy_index]
row_highest_accuracy
# Out:
# Dataset_index                                        16
# Name               noncir_mm_scaled_cir_stats_mm_scaled
# Train_Accuracy                                      1.0
# Train_Precision                                     1.0
# Test_Accuracy                                   0.91746
# Test_Precision                                 0.917904
# Name: 16, dtype: object

# %%
highest_accuracy_rows = result_df.sort_values(by='Test_Accuracy', ascending=False).iloc[:5]
highest_accuracy_rows
# Out:
#    Dataset_index                                          Name  \
# 16            16          noncir_mm_scaled_cir_stats_mm_scaled
# 31            31  noncir_ss_scaled_cir_stats_mm_scaled_trimmed
# 27            27                    noncir_ss_scaled_cir_stats
# 3              3                              noncir_cir_stats
# 18            18            noncir_mm_scaled_cir_stats_trimmed
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 16             1.0              1.0       0.917460        0.917904
# 31             1.0              1.0       0.917381        0.917856
# 27             1.0              1.0       0.917143        0.917604
# 3              1.0              1.0       0.917063        0.917468
# 18             1.0              1.0       0.916984        0.917319

# %%
result_df_filtered = result_df[~result_df['Train_Accuracy'].astype(str).str.split('.').str[0].str.startswith('1')]
result_df_filtered
# Out:
#    Dataset_index                                               Name  \
# 4              4                         noncir_cir_stats_mm_scaled
# 7              7                 noncir_cir_stats_mm_scaled_trimmed
# 12            12                               noncir_mm_scaled_cir
# 13            13                     noncir_mm_scaled_cir_mm_scaled
# 20            20       noncir_mm_scaled_cir_stats_ss_scaled_trimmed
# 22            22                 noncir_mm_scaled_cir_pca_mm_scaled
# 25            25                     noncir_ss_scaled_cir_mm_scaled
# 30            30                 noncir_ss_scaled_cir_stats_trimmed
# 41            41                 noncir_trimmed_cir_stats_ss_scaled
# 42            42                   noncir_trimmed_cir_stats_trimmed
# 57            57                   noncir_mm_scaled_trimmed_cir_pca
# 63            63                 noncir_ss_scaled_trimmed_cir_stats
# 65            65       noncir_ss_scaled_trimmed_cir_stats_ss_scaled
# 67            67  noncir_ss_scaled_trimmed_cir_stats_mm_scaled_t...
# 70            70         noncir_ss_scaled_trimmed_cir_pca_mm_scaled
#
#     Train_Accuracy  Train_Precision  Test_Accuracy  Test_Precision
# 4         0.999966         0.999966       0.915079        0.915462
# 7         0.999932         0.999932       0.916905        0.917309
# 12        0.999966         0.999966       0.872381        0.875860
# 13        0.999966         0.999966       0.873175        0.876590
# 20        0.999966         0.999966       0.916746        0.917150
# 22        0.999966         0.999966       0.902619        0.903686
# 25        0.999966         0.999966       0.874921        0.877775
# 30        0.999966         0.999966       0.916270        0.916657
# 41        0.999966         0.999966       0.914683        0.915252
# 42        0.999966         0.999966       0.914127        0.914604
# 57        0.999966         0.999966       0.904365        0.905183
# 63        0.999966         0.999966       0.915079        0.915513
# 65        0.999966         0.999966       0.915397        0.915922
# 67        0.999966         0.999966       0.916746        0.917249
# 70        0.999966         0.999966       0.905873        0.906847

# %%
num_rows_train_accuracy_1 = len(result_df[result_df['Train_Accuracy'].astype(str).str.startswith('1')])
print("Number of rows where train accuracy starts with 1:", num_rows_train_accuracy_1)
# Out:
# Number of rows where train accuracy starts with 1: 57

# %%
print(72-57)
# Out:
# 15

# %%
print(len(result_df_filtered))
# Out:
# 15
